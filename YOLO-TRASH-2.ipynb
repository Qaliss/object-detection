# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.8/949.8 kB 20.8 MB/s eta 0:00:0000:01
# ...

# %%
# !pip install opencv-python

# %%
# !pip install tensorflow==2.17.0 --no-deps
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 601.3/601.3 MB 2.9 MB/s eta 0:00:000:00:0100:01
# ...
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.17.1
#     Uninstalling tensorflow-2.17.1:
#       Successfully uninstalled tensorflow-2.17.1
# ...

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo checks
# Out:
# Ultralytics 8.3.94 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 6172.3/8062.4 GB disk)
#
# OS                  Linux-6.6.56+-x86_64-with-glibc2.35
# Environment         Colab
# Python              3.10.12
# Install             pip
# Path                /usr/local/lib/python3.10/dist-packages/ultralytics
# RAM                 31.35 GB
# Disk                6172.3/8062.4 GB
# CPU                 Intel Xeon 2.00GHz
# CPU count           4
# GPU                 Tesla P100-PCIE-16GB, 16269MiB
# GPU count           1
# CUDA                12.1
#
# numpy               ✅ 1.26.4<=2.1.1,>=1.23.0
# matplotlib          ✅ 3.7.5>=3.3.0
# opencv-python       ✅ 4.10.0.84>=4.6.0
# pillow              ✅ 11.0.0>=7.1.2
# pyyaml              ✅ 6.0.2>=5.3.1
# requests            ✅ 2.32.3>=2.23.0
# scipy               ✅ 1.13.1>=1.4.1
# torch               ✅ 2.5.1+cu121>=1.8.0
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="NR9XdFF23ArO8UpES26a")
project = rf.workspace("material-identification").project("garbage-classification-3")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 2.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to GARBAGE-CLASSIFICATION-3-2 in yolov8:: 100%|██████████| 20940/20940 [00:02<00:00, 9925.51it/s]

# %%
# !yolo task=detect mode=train model=yolov8m.pt data=/kaggle/input/garbage-classification/data.yaml epochs=20 imgsz=640 batch=-1
# Out:
# ...
# 100%|███████████████████████████████████████| 49.7M/49.7M [00:00<00:00, 177MB/s]
# Ultralytics 8.3.85 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
# !yolo task=detect mode=train model=/kaggle/input/detectionmodels/best.pt data=/kaggle/input/garbage-classification/data.yaml epochs=20 imgsz=640 batch=-1
# Out:
# Ultralytics 8.3.85 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
# !yolo task=detect mode=train model=/kaggle/input/detectionmodels2/best.pt data=/kaggle/input/garbage-classification/data.yaml epochs=20 imgsz=640 batch=-1
# Out:
# Ultralytics 8.3.85 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
# !yolo task=detect mode=train model=/kaggle/input/detectionmodels3/best.pt data=/kaggle/input/garbage-classification/data.yaml epochs=20 imgsz=640 batch=-1
# Out:
# Ultralytics 8.3.85 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
# !yolo task=detect mode=train model=/kaggle/input/detectionmodels4/best.pt data=/kaggle/input/garbage-classification/data.yaml epochs=20 imgsz=640 batch=-1
# Out:
# Ultralytics 8.3.86 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
# !yolo task=detect mode=train model=/kaggle/input/detectionmodels5/best.pt data=/kaggle/input/garbage-classification/data.yaml epochs=50 imgsz=640 batch=-1
# Out:
# Ultralytics 8.3.86 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="NR9XdFF23ArO8UpES26a")
project = rf.workspace("trash-ycdoj").project("garbage-classification-3-rsdwm")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 88.4 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov8 in progress : 85.0%
# Version export complete for yolov8 format
# ...
# Extracting Dataset Version Zip to GARBAGE-CLASSIFICATION-3-2 in yolov8:: 100%|██████████| 21030/21030 [00:03<00:00, 6850.36it/s]

# %%
# !yolo task=detect mode=train model=/kaggle/input/detectionmodels5/best.pt data=/kaggle/working/GARBAGE-CLASSIFICATION-3-2/data.yaml epochs=20 imgsz=640 batch=-1
# Out:
# Ultralytics 8.3.94 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...
