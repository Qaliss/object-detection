# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 921.5/921.5 kB 19.3 MB/s eta 0:00:0000:01
# ...

# %%
# !pip install opencv-python

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo checks
# Out:
# Ultralytics 8.3.78 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 6170.1/8062.4 GB disk)
#
# OS                  Linux-6.6.56+-x86_64-with-glibc2.35
# Environment         Colab
# Python              3.10.12
# Install             pip
# RAM                 31.35 GB
# Disk                6170.1/8062.4 GB
# CPU                 Intel Xeon 2.00GHz
# CPU count           4
# GPU                 Tesla P100-PCIE-16GB, 16269MiB
# GPU count           1
# CUDA                12.1
#
# numpy               ✅ 1.26.4<=2.1.1,>=1.23.0
# matplotlib          ✅ 3.7.5>=3.3.0
# opencv-python       ✅ 4.10.0.84>=4.6.0
# pillow              ✅ 11.0.0>=7.1.2
# pyyaml              ✅ 6.0.2>=5.3.1
# requests            ✅ 2.32.3>=2.23.0
# scipy               ✅ 1.13.1>=1.4.1
# torch               ✅ 2.5.1+cu121>=1.8.0
# torch               ✅ 2.5.1+cu121!=2.4.0,>=1.8.0; sys_platform == "win32"
# torchvision         ✅ 0.20.1+cu121>=0.9.0
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="NR9XdFF23ArO8UpES26a")
project = rf.workspace("projectverba").project("yolo-waste-detection")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.10.0 requires tensorflow==2.17.0, but you have tensorflow 2.17.1 which is incompatible.
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to YOLO-Waste-Detection-1 in yolov8:: 100%|██████████| 26220/26220 [00:02<00:00, 10009.24it/s]

# %%
# !pip install tensorflow==2.17.0 --no-deps
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 601.3/601.3 MB 3.1 MB/s eta 0:00:000:00:0100:01
# ...
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.17.1
#     Uninstalling tensorflow-2.17.1:
#       Successfully uninstalled tensorflow-2.17.1
# ...

# %%
# !pip install roboflow
from roboflow import Roboflow

# Initialize Roboflow with your API key
rf = Roboflow(api_key="NR9XdFF23ArO8UpES26a")  # Replace with your actual API key

# Fetch the dataset by its workspace and project name
project = rf.workspace("projectverba").project("yolo-waste-detection")
dataset = project.version(1).download("yolov5")  # "yolov5" is the YOLO format
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !yolo task=detect mode=train model=/kaggle/input/models/best.pt \
      data=/kaggle/input/wastedetection/data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics 8.3.78 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
# !yolo task=detect mode=train model=/kaggle/input/models2/best2.pt data=/kaggle/input/wastedetection/data.yaml epochs=20 imgsz=640 batch=-1
# Out:
# Ultralytics 8.3.78 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
from ultralytics import YOLO
model = YOLO('/kaggle/input/models2/last2.pt')  # Load last checkpoint
model.train(resume=True)
# Out:
# Ultralytics 8.3.78 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
# !yolo task=detect mode=train model=/kaggle/input/models2/best2.pt data=/kaggle/input/wastedetection/data.yaml epochs=20 imgsz=640 batch=-1
# Out:
# Ultralytics 8.3.78 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
# !yolo task=detect mode=/kaggle/input/models3/best3.pt \
      data=/kaggle/input/wastedetection/data.yaml epochs=30 imgsz=640
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 919, in entrypoint
#     raise ValueError(f"Invalid 'mode={mode}'. Valid modes are {MODES}.\n{CLI_HELP_MSG}")
# ValueError: Invalid 'mode=/kaggle/input/models3/best3.pt'. Valid modes are frozenset({'predict', 'export', 'benchmark', 'train', 'track', 'val'}).
#
#     Arguments received: ['yolo', 'task=detect', 'mode=/kaggle/input/models3/best3.pt', 'data=/kaggle/input/wastedetection/data.yaml', 'epochs=30', 'imgsz=640']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of frozenset({'pose', 'obb', 'classify', 'detect', 'segment'})
#                 MODE (required) is one of frozenset({'predict', 'export', 'benchmark', 'train', 'track', 'val'})
# ...

# %%
# !yolo task=detect mode=train model=/kaggle/input/models3/best3.pt data=/kaggle/input/wastedetection/data.yaml epochs=20 imgsz=640 batch=-1
# Out:
# Ultralytics 8.3.78 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...
